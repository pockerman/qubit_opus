# %% [markdown]
# # Matrix Approximation
# > "Matrix approximation with Singular Value Decomposition"
#
# - toc:false
# - branch: master
# - badges: false
# - comments: false
# - author: Alexandros Giavaras
# - categories: [linear-algebra, singular-value-decomposition, matrix-approximation, algorithms, numerics]

# %%
import numpy as np
from matplotlib import image
import matplotlib.pyplot as plt

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
# load image as pixel array
data = image.imread('my_icons/volvo_img.png')
data = rgb2gray(rgb=data)
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
plt.imshow(data)
plt.show()
# Out:
# float64
# (366, 424)

# %%
U, S, V = np.linalg.svd(data, full_matrices=True)

# %%
print("Shape U ", U.shape)
print("Shape S ", S.shape)
print("Shape V ", V.shape)
# Out:
# Shape U  (366, 366)
# Shape S  (366,)
# Shape V  (424, 424)

# %%
print("Matrix rank ", S.shape[0])
# Out:
# Matrix rank  366

# %%
for r in [5, 20, 100]:
    # construct approximate image
    Uapprox = U[:,:r]
    Sapprox = S[:r]
    Vapprox = V[:r,:]
    img_approx = np.dot(Uapprox, np.dot(np.diag(Sapprox), Vapprox))
    plt.imshow(img_approx)
    plt.show()
