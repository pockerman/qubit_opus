# %% [markdown]
# # Εκπομπές για την γενοκτονία των Ελλήνων  του Πόντου
#
#
# > "Διάγορες εκπομπές για την γενοκτονία των Ποντίων"
#
# - toc:true
# - branch: master
# - badges: false
# - comments: false
# - author: Alexandros Giavaras
# - categories: [history, pontiac-genocide, turkish-atrocities]

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('2C_O3hKpw-4', width=800, height=300)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('gjCqPYOpWb0', width=800, height=300)
