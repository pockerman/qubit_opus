# %% [markdown]
# # Η Τραγώδια Τής Κύπρου
#
# > "Σειρά εκπομπών με θέμα τήν τουρκική εισβολή στήν Κύπρο"
#
# - toc:false
# - branch: master
# - badges: false
# - comments: false
# - author: Alexandros Giavaras
# - categories: [ιστορία, κύπρος, εισβολή]

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UAdKpsdCQtc', width=800, height=300)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('00iwLvhAomQ', width=800, height=300)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('dDvmbjiorEM', width=800, height=300)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('BIs2Y_ndq7w', width=800, height=300)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9pdh_XnoFpM', width=800, height=300)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('f-pKhRLp4ko', width=800, height=300)
